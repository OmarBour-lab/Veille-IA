# %% [markdown]
# # 01 - Collecte des donnees\n
# \n
# Objectif : simuler ou executer une collecte de signaux de veille sur les frameworks IA.

# %%
from veille_agents import collect_market_items, filter_items

items = collect_market_items(use_live=True)
filtered = filter_items(items)

print(f'Items collectes : {len(items)}')
print(f'Items filtres : {len(filtered)}')
filtered[:3]
