# %% [markdown]
# # 05 - Generation du rapport\n
# \n
# Objectif : regenerer le rapport de synthese a partir des analyses sauvegardees.

# %%
from veille_agents import COLLECTED_DIR, REPORT_DIR, load_json, generate_report

analyses = load_json(COLLECTED_DIR / 'items_analyses.json')
report = generate_report(analyses)
print(REPORT_DIR / 'rapport_veille.md')
print(report[:1200])
