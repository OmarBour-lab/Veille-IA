# %% [markdown]
# # 03 - Pipeline multi-agents\n
# \n
# Objectif : executer le pipeline complet : collecte, filtrage, RAG, analyse, redaction.

# %%
from veille_agents import run_pipeline
result = run_pipeline(use_live=True)
result
