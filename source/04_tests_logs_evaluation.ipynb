# %% [markdown]
# # 04 - Tests, logs et evaluation\n
# \n
# Objectif : verifier que les agents produisent des traces et que les sorties respectent les contraintes anti-hallucination.

# %%
from pathlib import Path
from veille_agents import COLLECTED_DIR, LOG_DIR, load_json, evaluate_outputs

analyses_path = COLLECTED_DIR / 'items_analyses.json'
analyses = load_json(analyses_path)
evaluation = evaluate_outputs(analyses)

print(evaluation)
print('Logs disponibles :')
for path in sorted(LOG_DIR.glob('*.log')):
    print('-', path.name, path.stat().st_size, 'octets')
