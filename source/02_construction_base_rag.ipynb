# %% [markdown]
# # 02 - Construction de la base RAG\n
# \n
# Objectif : charger la base interne simulee, decouper les documents en chunks et tester le retrieval.

# %%
from veille_agents import build_chunks, retrieve

chunks = build_chunks(chunk_size=120, overlap=25)
print(f'Nombre de chunks : {len(chunks)}')

query = 'LlamaIndex RAG documents internes citations'
results = retrieve(query, chunks, top_k=3)
results
